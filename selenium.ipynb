# %%
# !pip install chromedriver

# %%
from selenium import webdriver
path=r"C:\Users\Deepak Goswami\Desktop\chromedriver\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get('https://me.cleartrip.com/hotels/united-states/dallas?page=2')
review = driver.find_elements_by_class_name('hotels-card')

# %%
for post in review:
    print(post.text)
# Out:
# W Dallas - Victory
# Oak Lawn
# 704 reviews
# Air Conditioner
# Restaurant
# Bar
# Room Service
# Internet
# Pool
# Property Location: With a stay at W Dallas - Victory in Dallas (Oak Lawn), you'll be minutes from Victory Park and American Airlines Center
# ₹ 25593 / night
# The Fairmont Dallas
# Downtown Dallas
# 1222 reviews
# Air Conditioner
# Restaurant
# Bar
# Cafe
# Room Service
# Internet
# Pool
# Property Location: With a stay at The Fairmont Dallas, you'll be centrally located in Dallas, steps from Dallas Museum of Art and minutes from Dallas World Aquarium
# ₹ 17036 / night
# Magnolia Hotel Dallas Downtown
# Downtown Dallas
# 2588 reviews
# Air Conditioner
# Restaurant
# Bar
# Cafe
# Room Service
# Internet
# Property Location: Magnolia Hotel Dallas Downtown is in the heart of Dallas, walking distance from Comerica Bank Tower and Renaissance Tower
# ₹ 11505 / night
# Omni Dallas Park West
# 861 reviews
# Room Service
# Pool
# Gym
# Superior First Class Hotel
# Check Price
# ...

# %%
from selenium import webdriver
path=r"C:\Users\Deepak Goswami\Desktop\chromedriver\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get('https://me.cleartrip.com/hotels/details/154260?c=080619|090619&r=2,0')
review = driver.find_elements_by_class_name('amenitiesCategory')
for post in review:
    print(post.text)
# Out:
# About the Hotel
# Property Location: With a stay at W Dallas - Victory in Dallas (Oak Lawn), you'll be a 5-minute walk from American Airlines Center and 13 minutes by foot from Dallas World Aquarium. This 4-star hotel is 0.7 mi (1.1 km) from Sixth Floor Museum and 1 mi (1.6 km) from Morton H. Meyerson Symphony Center.
# Continue reading
# Quick facts
# 3 PM
# Check-in
# 12 PM
# Check-out
# 252
# Rooms
# 33
# Floors
# General
# 24 Hour Front Desk
# ATM/Cash Machine
# Air Conditioning
# Elevator
# Housekeeping
# Interconnecting Rooms
# Internet
# Laundry
# Food & Beverage
# 24 Hour Room Service
# Banquet Hall
# Bar
# Lounge
# Restaurant
# Room Service
# Business Services
# Audio Visual Equipment
# Business Centre
# Meeting Room
# Front Desk Services
# Concierge
# Travel
# Limousine Service
# Parking
# Pick & Drop
# Porter
# Valet Parking
# Recreation
# Beauty Salon
# Fitness Centre
# Gift Shop
# Massage Centre
# Nightclub
# Sauna
# Spa
# Swimming Pool
# Kids
# Babysitting
